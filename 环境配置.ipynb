# %% [markdown]
# <a href="https://colab.research.google.com/github/Wuito/Nebor2Nebor/blob/main/%E7%8E%AF%E5%A2%83%E9%85%8D%E7%BD%AE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Neighbor2Neighbor环境配置
#
# 修改python版本为py3.7

# %%
# !python --version
# !apt-get install python3.7
# !cp -r /usr/local/lib/python3.8/dist-packages /usr/local/lib/python3.7/
# Out:
# Python 3.8.16
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libpython3.7-minimal libpython3.7-stdlib python3.7-minimal
# Suggested packages:
#   python3.7-venv binfmt-support
# The following NEW packages will be installed:
#   libpython3.7-minimal libpython3.7-stdlib python3.7 python3.7-minimal
# 0 upgraded, 4 newly installed, 0 to remove and 21 not upgraded.
# Need to get 4,448 kB of archives.
# After this operation, 22.5 MB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 libpython3.7-minimal amd64 3.7.16-1+bionic1 [589 kB]
# Get:2 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 python3.7-minimal amd64 3.7.16-1+bionic1 [1,725 kB]
# Get:3 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 libpython3.7-stdlib amd64 3.7.16-1+bionic1 [1,773 kB]
# Get:4 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 python3.7 amd64 3.7.16-1+bionic1 [360 kB]
# Fetched 4,448 kB in 6s (797 kB/s)
# Selecting previously unselected package libpython3.7-minimal:amd64.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../libpython3.7-minimal_3.7.16-1+bionic1_amd64.deb ...
# Unpacking libpython3.7-minimal:amd64 (3.7.16-1+bionic1) ...
# Selecting previously unselected package python3.7-minimal.
# Preparing to unpack .../python3.7-minimal_3.7.16-1+bionic1_amd64.deb ...
# Unpacking python3.7-minimal (3.7.16-1+bionic1) ...
# Selecting previously unselected package libpython3.7-stdlib:amd64.
# Preparing to unpack .../libpython3.7-stdlib_3.7.16-1+bionic1_amd64.deb ...
# Unpacking libpython3.7-stdlib:amd64 (3.7.16-1+bionic1) ...
# Selecting previously unselected package python3.7.
# Preparing to unpack .../python3.7_3.7.16-1+bionic1_amd64.deb ...
# Unpacking python3.7 (3.7.16-1+bionic1) ...
# Setting up libpython3.7-minimal:amd64 (3.7.16-1+bionic1) ...
# Setting up python3.7-minimal (3.7.16-1+bionic1) ...
# Setting up libpython3.7-stdlib:amd64 (3.7.16-1+bionic1) ...
# Setting up python3.7 (3.7.16-1+bionic1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...

# %% [markdown]
# 卸载高版本的安装包

# %%
# !python3.7 -m pip uninstall numpy
# Out:
# Found existing installation: numpy 1.21.6
# Uninstalling numpy-1.21.6:
#   Would remove:
#     /usr/bin/f2py
#     /usr/local/bin/f2py
#     /usr/local/bin/f2py3
#     /usr/local/bin/f2py3.8
#     /usr/local/lib/python3.7/dist-packages/numpy-1.21.6.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/numpy.libs/libgfortran-2e0d59d6.so.5.0.0
#     /usr/local/lib/python3.7/dist-packages/numpy.libs/libopenblasp-r0-2d23e62b.3.17.so
#     /usr/local/lib/python3.7/dist-packages/numpy.libs/libquadmath-2d0c479f.so.0.0.0
#     /usr/local/lib/python3.7/dist-packages/numpy/*
# Proceed (Y/n)? y
#   Successfully uninstalled numpy-1.21.6

# %% [markdown]
# 安装需求版本的安装包, https://download.pytorch.org/whl/torch_stable.html

# %%
# !python3.7 -m pip install torch==1.4
# !python3.7 -m pip install torchvision
# !python3.7 -m pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torch==1.4
#   Downloading torch-1.4.0-cp37-cp37m-manylinux1_x86_64.whl (753.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 753.4/753.4 MB 2.1 MB/s eta 0:00:00
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.0+cu116
#     Uninstalling torch-1.13.0+cu116:
#       Successfully uninstalled torch-1.13.0+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.14.0+cu116 requires numpy, which is not installed.
# torchtext 0.14.0 requires numpy, which is not installed.
# torchvision 0.14.0+cu116 requires torch==1.13.0, but you have torch 1.4.0 which is incompatible.
# torchtext 0.14.0 requires torch==1.13.0, but you have torch 1.4.0 which is incompatible.
# torchaudio 0.13.0+cu116 requires torch==1.13.0, but you have torch 1.4.0 which is incompatible.
# fastai 2.7.10 requires torch<1.14,>=1.7, but you have torch 1.4.0 which is incompatible.
# Successfully installed torch-1.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (0.14.0+cu116)
# Collecting numpy
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 68.1 MB/s eta 0:00:00
# Collecting torch==1.13.0
#   Downloading torch-1.13.0-cp37-cp37m-manylinux1_x86_64.whl (890.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 890.2/890.2 MB 194.6 MB/s eta 0:00:01tcmalloc: large alloc 1112801280 bytes == 0x3a3a0000 @  0x7f55817a6615 0x58d706 0x4f750e 0x4d1d5f 0x5143bc 0x5a5fb6 0x58eb5e 0x5109d7 0x5a5fb6 0x58eb5e 0x5109d7 0x5a5fb6 0x58eb5e 0x5109d7 0x5a5fb6 0x58eb5e 0x5109d7 0x5a5fb6 0x58eb5e 0x5109d7 0x58e967 0x5109d7 0x5a5fb6 0x58eb5e 0x511421 0x5a5fb6 0x58eb5e 0x5109d7 0x5a5fb6 0x4bd9c9 0x4d2d69
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 890.2/890.2 MB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchvision) (4.4.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision) (2.25.1)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.7 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 64.2 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 KB 60.9 MB/s eta 0:00:00
# Requirement already satisfied: wheel in /usr/local/lib/python3.7/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision) (0.38.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.0->torchvision) (57.4.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision) (1.24.3)
# Installing collected packages: nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, numpy, nvidia-cudnn-cu11, torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.4.0
#     Uninstalling torch-1.4.0:
#       Successfully uninstalled torch-1.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# h5py 3.1.0 requires cached-property; python_version < "3.8", which is not installed.
# thinc 8.1.6 requires typing-extensions<4.2.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.
# spacy 3.4.4 requires typing-extensions<4.2.0,>=3.7.4; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.
# Successfully installed numpy-1.21.6 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 torch-1.13.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)

# %% [markdown]
# 挂载Google Driver

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 124632 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.27-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.27-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.27-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=None&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force

# %% [markdown]
# 挂载内容

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# Out:
# /bin/bash: google-drive-ocamlfuse: command not found

# %% [markdown]
# 修改路径

# %%
import os
import sys
os.chdir('drive/MyDrive/Colab Notebooks/Neighbor2Neighbor-main')
# !ls
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-13-3c2fb85dbad5> in <module>
#       1 import os
#       2 import sys
# ----> 3 os.chdir('drive/MyDrive/Colab Notebooks/Neighbor2Neighbor-main')
#       4 get_ipython().system('ls')
#       5 get_ipython().system('nvcc --version')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'drive/MyDrive/Colab Notebooks/Neighbor2Neighbor-main'

# %%
# !nvcc --version
# !sudo lsb_release -a
# !wget https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# !sudo mv cuda-ubuntu1804.pin /etc/apt/preferences.d/cuda-repository-pin-600
# !wget https://developer.download.nvidia.com/compute/cuda/12.0.0/local_installers/cuda-repo-ubuntu1804-12-0-local_12.0.0-525.60.13-1_amd64.deb
# !sudo dpkg -i cuda-repo-ubuntu1804-12-0-local_12.0.0-525.60.13-1_amd64.deb
# !sudo cp /var/cuda-repo-ubuntu1804-12-0-local/cuda-*-keyring.gpg /usr/share/keyrings/
# !sudo apt-get update
# !sudo apt-get -y install cuda
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2021 NVIDIA Corporation
# Built on Sun_Feb_14_21:12:58_PST_2021
# Cuda compilation tools, release 11.2, V11.2.152
# Build cuda_11.2.r11.2/compiler.29618528_0
# No LSB modules are available.
# Distributor ID:	Ubuntu
# Description:	Ubuntu 18.04.6 LTS
# Release:	18.04
# Codename:	bionic
# --2023-01-06 18:34:16--  https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64/cuda-ubuntu1804.pin
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 190 [application/octet-stream]
# Saving to: ‘cuda-ubuntu1804.pin’
#
# cuda-ubuntu1804.pin 100%[===================>]     190  --.-KB/s    in 0s
#
# 2023-01-06 18:34:16 (9.81 MB/s) - ‘cuda-ubuntu1804.pin’ saved [190/190]
#
# --2023-01-06 18:34:16--  https://developer.download.nvidia.com/compute/cuda/12.0.0/local_installers/cuda-repo-ubuntu1804-12-0-local_12.0.0-525.60.13-1_amd64.deb
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 152.199.39.144
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3063616888 (2.9G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1804-12-0-local_12.0.0-525.60.13-1_amd64.deb’
#
# cuda-repo-ubuntu180 100%[===================>]   2.85G  68.3MB/s    in 44s
#
# 2023-01-06 18:35:00 (66.3 MB/s) - ‘cuda-repo-ubuntu1804-12-0-local_12.0.0-525.60.13-1_amd64.deb’ saved [3063616888/3063616888]
#
# Selecting previously unselected package cuda-repo-ubuntu1804-12-0-local.
# (Reading database ... 124632 files and directories currently installed.)
# Preparing to unpack cuda-repo-ubuntu1804-12-0-local_12.0.0-525.60.13-1_amd64.deb ...
# Unpacking cuda-repo-ubuntu1804-12-0-local (12.0.0-525.60.13-1) ...
# Setting up cuda-repo-ubuntu1804-12-0-local (12.0.0-525.60.13-1) ...
#
# The public cuda-repo-ubuntu1804-12-0-local GPG key does not appear to be installed.
# To install the key, run this command:
# sudo cp /var/cuda-repo-ubuntu1804-12-0-local/cuda-C8749C0D-keyring.gpg /usr/share/keyrings/
#
# Get:1 file:/var/cuda-repo-ubuntu1804-12-0-local  InRelease [1,575 B]
# Get:1 file:/var/cuda-repo-ubuntu1804-12-0-local  InRelease [1,575 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:3 file:/var/cuda-repo-ubuntu1804-12-0-local  Packages [34.5 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:9 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:11 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:13 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Get:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [83.3 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,348 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [3,127 kB]
# Get:18 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [43.2 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [1,389 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [3,549 kB]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,573 kB]
# Get:22 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [1,349 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [30.9 kB]
# Fetched 13.7 MB in 5s (3,031 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   cuda-12-0 cuda-cccl-12-0 cuda-command-line-tools-12-0 cuda-compiler-12-0
#   cuda-cudart-12-0 cuda-cudart-dev-12-0 cuda-cuobjdump-12-0 cuda-cupti-12-0
#   cuda-cupti-dev-12-0 cuda-cuxxfilt-12-0 cuda-demo-suite-12-0
#   cuda-documentation-12-0 cuda-driver-dev-12-0 cuda-gdb-12-0
#   cuda-libraries-12-0 cuda-libraries-dev-12-0 cuda-nsight-12-0
#   cuda-nsight-compute-12-0 cuda-nsight-systems-12-0 cuda-nvcc-12-0
#   cuda-nvdisasm-12-0 cuda-nvml-dev-12-0 cuda-nvprof-12-0 cuda-nvprune-12-0
#   cuda-nvrtc-12-0 cuda-nvrtc-dev-12-0 cuda-nvtx-12-0 cuda-nvvp-12-0
#   cuda-opencl-12-0 cuda-opencl-dev-12-0 cuda-profiler-api-12-0
#   cuda-runtime-12-0 cuda-sanitizer-12-0 cuda-toolkit-12-0
#   cuda-toolkit-12-0-config-common cuda-toolkit-12-config-common
#   cuda-toolkit-config-common cuda-tools-12-0 cuda-visual-tools-12-0
#   gds-tools-12-0 libcublas-12-0 libcublas-dev-12-0 libcufft-12-0
#   libcufft-dev-12-0 libcufile-12-0 libcufile-dev-12-0 libcurand-12-0
#   libcurand-dev-12-0 libcusolver-12-0 libcusolver-dev-12-0 libcusparse-12-0
#   libcusparse-dev-12-0 libnpp-12-0 libnpp-dev-12-0 libnvjitlink-12-0
#   libnvjitlink-dev-12-0 libnvjpeg-12-0 libnvjpeg-dev-12-0 libnvvm-samples-12-0
#   libxcb-xinput0 nsight-compute-2022.4.0 nsight-systems-2022.4.2
# The following NEW packages will be installed:
#   cuda cuda-12-0 cuda-cccl-12-0 cuda-command-line-tools-12-0
#   cuda-compiler-12-0 cuda-cudart-12-0 cuda-cudart-dev-12-0 cuda-cuobjdump-12-0
#   cuda-cupti-12-0 cuda-cupti-dev-12-0 cuda-cuxxfilt-12-0 cuda-demo-suite-12-0
#   cuda-documentation-12-0 cuda-driver-dev-12-0 cuda-gdb-12-0
#   cuda-libraries-12-0 cuda-libraries-dev-12-0 cuda-nsight-12-0
#   cuda-nsight-compute-12-0 cuda-nsight-systems-12-0 cuda-nvcc-12-0
#   cuda-nvdisasm-12-0 cuda-nvml-dev-12-0 cuda-nvprof-12-0 cuda-nvprune-12-0
#   cuda-nvrtc-12-0 cuda-nvrtc-dev-12-0 cuda-nvtx-12-0 cuda-nvvp-12-0
#   cuda-opencl-12-0 cuda-opencl-dev-12-0 cuda-profiler-api-12-0
#   cuda-runtime-12-0 cuda-sanitizer-12-0 cuda-toolkit-12-0
#   cuda-toolkit-12-0-config-common cuda-toolkit-12-config-common
#   cuda-toolkit-config-common cuda-tools-12-0 cuda-visual-tools-12-0
#   gds-tools-12-0 libcublas-12-0 libcublas-dev-12-0 libcufft-12-0
#   libcufft-dev-12-0 libcufile-12-0 libcufile-dev-12-0 libcurand-12-0
#   libcurand-dev-12-0 libcusolver-12-0 libcusolver-dev-12-0 libcusparse-12-0
#   libcusparse-dev-12-0 libnpp-12-0 libnpp-dev-12-0 libnvjitlink-12-0
#   libnvjitlink-dev-12-0 libnvjpeg-12-0 libnvjpeg-dev-12-0 libnvvm-samples-12-0
#   libxcb-xinput0 nsight-compute-2022.4.0 nsight-systems-2022.4.2
# 0 upgraded, 63 newly installed, 0 to remove and 26 not upgraded.
# Need to get 29.3 kB/2,587 MB of archives.
# After this operation, 6,564 MB of additional disk space will be used.
# Get:1 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-toolkit-config-common 12.0.107-1 [16.4 kB]
# Get:2 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-toolkit-12-config-common 12.0.107-1 [16.4 kB]
# Get:3 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-toolkit-12-0-config-common 12.0.107-1 [16.3 kB]
# Get:4 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-cudart-12-0 12.0.107-1 [159 kB]
# Get:5 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-nvrtc-12-0 12.0.76-1 [16.7 MB]
# Get:6 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-opencl-12-0 12.0.76-1 [23.8 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-xinput0 amd64 1.13-2~ubuntu18.04 [29.3 kB]
# Get:8 file:/var/cuda-repo-ubuntu1804-12-0-local  libcublas-12-0 12.0.1.189-1 [223 MB]
# Get:9 file:/var/cuda-repo-ubuntu1804-12-0-local  libcufft-12-0 11.0.0.21-1 [42.7 MB]
# Get:10 file:/var/cuda-repo-ubuntu1804-12-0-local  libcufile-12-0 1.5.0.59-1 [635 kB]
# Get:11 file:/var/cuda-repo-ubuntu1804-12-0-local  libcurand-12-0 10.3.1.50-1 [41.5 MB]
# Get:12 file:/var/cuda-repo-ubuntu1804-12-0-local  libcusolver-12-0 11.4.2.57-1 [51.3 MB]
# Get:13 file:/var/cuda-repo-ubuntu1804-12-0-local  libcusparse-12-0 12.0.0.76-1 [93.9 MB]
# Get:14 file:/var/cuda-repo-ubuntu1804-12-0-local  libnpp-12-0 12.0.0.30-1 [95.3 MB]
# Get:15 file:/var/cuda-repo-ubuntu1804-12-0-local  libnvjitlink-12-0 12.0.76-1 [14.6 MB]
# Get:16 file:/var/cuda-repo-ubuntu1804-12-0-local  libnvjpeg-12-0 12.0.0.28-1 [1,761 kB]
# Get:17 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-libraries-12-0 12.0.0-1 [2,540 B]
# Get:18 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-runtime-12-0 12.0.0-1 [2,430 B]
# Get:19 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-cuobjdump-12-0 12.0.76-1 [167 kB]
# Get:20 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-cuxxfilt-12-0 12.0.76-1 [189 kB]
# Get:21 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-cccl-12-0 12.0.90-1 [1,060 kB]
# Get:22 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-driver-dev-12-0 12.0.107-1 [27.9 kB]
# Get:23 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-cudart-dev-12-0 12.0.107-1 [886 kB]
# Get:24 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-nvcc-12-0 12.0.76-1 [44.3 MB]
# Get:25 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-nvprune-12-0 12.0.76-1 [58.6 kB]
# Get:26 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-compiler-12-0 12.0.0-1 [2,436 B]
# Get:27 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-profiler-api-12-0 12.0.76-1 [18.5 kB]
# Get:28 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-nvrtc-dev-12-0 12.0.76-1 [13.8 MB]
# Get:29 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-opencl-dev-12-0 12.0.76-1 [64.7 kB]
# Get:30 file:/var/cuda-repo-ubuntu1804-12-0-local  libcublas-dev-12-0 12.0.1.189-1 [236 MB]
# Get:31 file:/var/cuda-repo-ubuntu1804-12-0-local  libcufft-dev-12-0 11.0.0.21-1 [85.9 MB]
# Get:32 file:/var/cuda-repo-ubuntu1804-12-0-local  libcufile-dev-12-0 1.5.0.59-1 [1,561 kB]
# Get:33 file:/var/cuda-repo-ubuntu1804-12-0-local  libcurand-dev-12-0 10.3.1.50-1 [41.7 MB]
# Get:34 file:/var/cuda-repo-ubuntu1804-12-0-local  libcusolver-dev-12-0 11.4.2.57-1 [33.7 MB]
# Get:35 file:/var/cuda-repo-ubuntu1804-12-0-local  libcusparse-dev-12-0 12.0.0.76-1 [95.7 MB]
# Get:36 file:/var/cuda-repo-ubuntu1804-12-0-local  libnpp-dev-12-0 12.0.0.30-1 [92.8 MB]
# Get:37 file:/var/cuda-repo-ubuntu1804-12-0-local  libnvjitlink-dev-12-0 12.0.76-1 [11.4 MB]
# Get:38 file:/var/cuda-repo-ubuntu1804-12-0-local  libnvjpeg-dev-12-0 12.0.0.28-1 [1,436 kB]
# Get:39 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-libraries-dev-12-0 12.0.0-1 [2,580 B]
# Get:40 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-cupti-12-0 12.0.90-1 [16.3 MB]
# Get:41 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-cupti-dev-12-0 12.0.90-1 [2,542 kB]
# Get:42 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-nvdisasm-12-0 12.0.76-1 [49.9 MB]
# Get:43 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-gdb-12-0 12.0.90-1 [4,538 kB]
# Get:44 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-nvprof-12-0 12.0.90-1 [1,960 kB]
# Get:45 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-nvtx-12-0 12.0.76-1 [51.4 kB]
# Get:46 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-sanitizer-12-0 12.0.90-1 [8,831 kB]
# Get:47 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-command-line-tools-12-0 12.0.0-1 [2,478 B]
# Get:48 file:/var/cuda-repo-ubuntu1804-12-0-local  nsight-compute-2022.4.0 2022.4.0.15-1 [700 MB]
# Get:49 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-nsight-compute-12-0 12.0.0-1 [3,942 B]
# Get:50 file:/var/cuda-repo-ubuntu1804-12-0-local  nsight-systems-2022.4.2 2022.4.2.18-32044700v0 [286 MB]
# Get:51 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-nsight-systems-12-0 12.0.0-1 [3,342 B]
# Get:52 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-nsight-12-0 12.0.78-1 [119 MB]
# Get:53 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-nvml-dev-12-0 12.0.76-1 [84.7 kB]
# Get:54 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-nvvp-12-0 12.0.90-1 [113 MB]
# Get:55 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-visual-tools-12-0 12.0.0-1 [2,878 B]
# Get:56 file:/var/cuda-repo-ubuntu1804-12-0-local  gds-tools-12-0 1.5.0.59-1 [39.2 MB]
# Get:57 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-tools-12-0 12.0.0-1 [2,396 B]
# Get:58 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-documentation-12-0 12.0.76-1 [49.9 kB]
# Get:59 file:/var/cuda-repo-ubuntu1804-12-0-local  libnvvm-samples-12-0 12.0.94-1 [31.8 kB]
# Get:60 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-toolkit-12-0 12.0.0-1 [3,254 B]
# Get:61 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-demo-suite-12-0 12.0.76-1 [3,984 kB]
# Get:62 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda-12-0 12.0.0-1 [2,456 B]
# Get:63 file:/var/cuda-repo-ubuntu1804-12-0-local  cuda 12.0.0-1 [2,404 B]
# Fetched 29.3 kB in 42s (706 B/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 63.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package cuda-toolkit-config-common.
# (Reading database ... 124770 files and directories currently installed.)
# Preparing to unpack .../00-cuda-toolkit-config-common_12.0.107-1_all.deb ...
# Unpacking cuda-toolkit-config-common (12.0.107-1) ...
# dpkg: error processing archive /tmp/apt-dpkg-install-Edjpw3/00-cuda-toolkit-config-common_12.0.107-1_all.deb (--unpack):
#  trying to overwrite '/etc/ld.so.conf.d/000_cuda.conf', which is also in package cuda-cudart-11-2 11.2.152-1
# Selecting previously unselected package cuda-toolkit-12-config-common.
# Preparing to unpack .../01-cuda-toolkit-12-config-common_12.0.107-1_all.deb ...
# Unpacking cuda-toolkit-12-config-common (12.0.107-1) ...
# Selecting previously unselected package cuda-toolkit-12-0-config-common.
# Preparing to unpack .../02-cuda-toolkit-12-0-config-common_12.0.107-1_all.deb ...
# Unpacking cuda-toolkit-12-0-config-common (12.0.107-1) ...
# Selecting previously unselected package cuda-cudart-12-0.
# Preparing to unpack .../03-cuda-cudart-12-0_12.0.107-1_amd64.deb ...
# Unpacking cuda-cudart-12-0 (12.0.107-1) ...
# Selecting previously unselected package cuda-nvrtc-12-0.
# Preparing to unpack .../04-cuda-nvrtc-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-nvrtc-12-0 (12.0.76-1) ...
# Selecting previously unselected package cuda-opencl-12-0.
# Preparing to unpack .../05-cuda-opencl-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-opencl-12-0 (12.0.76-1) ...
# Selecting previously unselected package libcublas-12-0.
# Preparing to unpack .../06-libcublas-12-0_12.0.1.189-1_amd64.deb ...
# Unpacking libcublas-12-0 (12.0.1.189-1) ...
# Selecting previously unselected package libcufft-12-0.
# Preparing to unpack .../07-libcufft-12-0_11.0.0.21-1_amd64.deb ...
# Unpacking libcufft-12-0 (11.0.0.21-1) ...
# Selecting previously unselected package libcufile-12-0.
# Preparing to unpack .../08-libcufile-12-0_1.5.0.59-1_amd64.deb ...
# Unpacking libcufile-12-0 (1.5.0.59-1) ...
# Selecting previously unselected package libcurand-12-0.
# Preparing to unpack .../09-libcurand-12-0_10.3.1.50-1_amd64.deb ...
# Unpacking libcurand-12-0 (10.3.1.50-1) ...
# Selecting previously unselected package libcusolver-12-0.
# Preparing to unpack .../10-libcusolver-12-0_11.4.2.57-1_amd64.deb ...
# Unpacking libcusolver-12-0 (11.4.2.57-1) ...
# Selecting previously unselected package libcusparse-12-0.
# Preparing to unpack .../11-libcusparse-12-0_12.0.0.76-1_amd64.deb ...
# Unpacking libcusparse-12-0 (12.0.0.76-1) ...
# Selecting previously unselected package libnpp-12-0.
# Preparing to unpack .../12-libnpp-12-0_12.0.0.30-1_amd64.deb ...
# Unpacking libnpp-12-0 (12.0.0.30-1) ...
# Selecting previously unselected package libnvjitlink-12-0.
# Preparing to unpack .../13-libnvjitlink-12-0_12.0.76-1_amd64.deb ...
# Unpacking libnvjitlink-12-0 (12.0.76-1) ...
# Selecting previously unselected package libnvjpeg-12-0.
# Preparing to unpack .../14-libnvjpeg-12-0_12.0.0.28-1_amd64.deb ...
# Unpacking libnvjpeg-12-0 (12.0.0.28-1) ...
# Selecting previously unselected package cuda-libraries-12-0.
# Preparing to unpack .../15-cuda-libraries-12-0_12.0.0-1_amd64.deb ...
# Unpacking cuda-libraries-12-0 (12.0.0-1) ...
# Selecting previously unselected package cuda-runtime-12-0.
# Preparing to unpack .../16-cuda-runtime-12-0_12.0.0-1_amd64.deb ...
# Unpacking cuda-runtime-12-0 (12.0.0-1) ...
# Selecting previously unselected package cuda-cuobjdump-12-0.
# Preparing to unpack .../17-cuda-cuobjdump-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-cuobjdump-12-0 (12.0.76-1) ...
# Selecting previously unselected package cuda-cuxxfilt-12-0.
# Preparing to unpack .../18-cuda-cuxxfilt-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-cuxxfilt-12-0 (12.0.76-1) ...
# Selecting previously unselected package cuda-cccl-12-0.
# Preparing to unpack .../19-cuda-cccl-12-0_12.0.90-1_amd64.deb ...
# Unpacking cuda-cccl-12-0 (12.0.90-1) ...
# Selecting previously unselected package cuda-driver-dev-12-0.
# Preparing to unpack .../20-cuda-driver-dev-12-0_12.0.107-1_amd64.deb ...
# Unpacking cuda-driver-dev-12-0 (12.0.107-1) ...
# Selecting previously unselected package cuda-cudart-dev-12-0.
# Preparing to unpack .../21-cuda-cudart-dev-12-0_12.0.107-1_amd64.deb ...
# Unpacking cuda-cudart-dev-12-0 (12.0.107-1) ...
# Selecting previously unselected package cuda-nvcc-12-0.
# Preparing to unpack .../22-cuda-nvcc-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-nvcc-12-0 (12.0.76-1) ...
# Selecting previously unselected package cuda-nvprune-12-0.
# Preparing to unpack .../23-cuda-nvprune-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-nvprune-12-0 (12.0.76-1) ...
# Selecting previously unselected package cuda-compiler-12-0.
# Preparing to unpack .../24-cuda-compiler-12-0_12.0.0-1_amd64.deb ...
# Unpacking cuda-compiler-12-0 (12.0.0-1) ...
# Selecting previously unselected package cuda-profiler-api-12-0.
# Preparing to unpack .../25-cuda-profiler-api-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-profiler-api-12-0 (12.0.76-1) ...
# Selecting previously unselected package cuda-nvrtc-dev-12-0.
# Preparing to unpack .../26-cuda-nvrtc-dev-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-nvrtc-dev-12-0 (12.0.76-1) ...
# Selecting previously unselected package cuda-opencl-dev-12-0.
# Preparing to unpack .../27-cuda-opencl-dev-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-opencl-dev-12-0 (12.0.76-1) ...
# Selecting previously unselected package libcublas-dev-12-0.
# Preparing to unpack .../28-libcublas-dev-12-0_12.0.1.189-1_amd64.deb ...
# Unpacking libcublas-dev-12-0 (12.0.1.189-1) ...
# Selecting previously unselected package libcufft-dev-12-0.
# Preparing to unpack .../29-libcufft-dev-12-0_11.0.0.21-1_amd64.deb ...
# Unpacking libcufft-dev-12-0 (11.0.0.21-1) ...
# Selecting previously unselected package libcufile-dev-12-0.
# Preparing to unpack .../30-libcufile-dev-12-0_1.5.0.59-1_amd64.deb ...
# Unpacking libcufile-dev-12-0 (1.5.0.59-1) ...
# Selecting previously unselected package libcurand-dev-12-0.
# Preparing to unpack .../31-libcurand-dev-12-0_10.3.1.50-1_amd64.deb ...
# Unpacking libcurand-dev-12-0 (10.3.1.50-1) ...
# Selecting previously unselected package libcusolver-dev-12-0.
# Preparing to unpack .../32-libcusolver-dev-12-0_11.4.2.57-1_amd64.deb ...
# Unpacking libcusolver-dev-12-0 (11.4.2.57-1) ...
# Selecting previously unselected package libcusparse-dev-12-0.
# Preparing to unpack .../33-libcusparse-dev-12-0_12.0.0.76-1_amd64.deb ...
# Unpacking libcusparse-dev-12-0 (12.0.0.76-1) ...
# Selecting previously unselected package libnpp-dev-12-0.
# Preparing to unpack .../34-libnpp-dev-12-0_12.0.0.30-1_amd64.deb ...
# Unpacking libnpp-dev-12-0 (12.0.0.30-1) ...
# Selecting previously unselected package libnvjitlink-dev-12-0.
# Preparing to unpack .../35-libnvjitlink-dev-12-0_12.0.76-1_amd64.deb ...
# Unpacking libnvjitlink-dev-12-0 (12.0.76-1) ...
# Selecting previously unselected package libnvjpeg-dev-12-0.
# Preparing to unpack .../36-libnvjpeg-dev-12-0_12.0.0.28-1_amd64.deb ...
# Unpacking libnvjpeg-dev-12-0 (12.0.0.28-1) ...
# Selecting previously unselected package cuda-libraries-dev-12-0.
# Preparing to unpack .../37-cuda-libraries-dev-12-0_12.0.0-1_amd64.deb ...
# Unpacking cuda-libraries-dev-12-0 (12.0.0-1) ...
# Selecting previously unselected package cuda-cupti-12-0.
# Preparing to unpack .../38-cuda-cupti-12-0_12.0.90-1_amd64.deb ...
# Unpacking cuda-cupti-12-0 (12.0.90-1) ...
# Selecting previously unselected package cuda-cupti-dev-12-0.
# Preparing to unpack .../39-cuda-cupti-dev-12-0_12.0.90-1_amd64.deb ...
# Unpacking cuda-cupti-dev-12-0 (12.0.90-1) ...
# Selecting previously unselected package cuda-nvdisasm-12-0.
# Preparing to unpack .../40-cuda-nvdisasm-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-nvdisasm-12-0 (12.0.76-1) ...
# Selecting previously unselected package cuda-gdb-12-0.
# Preparing to unpack .../41-cuda-gdb-12-0_12.0.90-1_amd64.deb ...
# Unpacking cuda-gdb-12-0 (12.0.90-1) ...
# Selecting previously unselected package cuda-nvprof-12-0.
# Preparing to unpack .../42-cuda-nvprof-12-0_12.0.90-1_amd64.deb ...
# Unpacking cuda-nvprof-12-0 (12.0.90-1) ...
# Selecting previously unselected package cuda-nvtx-12-0.
# Preparing to unpack .../43-cuda-nvtx-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-nvtx-12-0 (12.0.76-1) ...
# Selecting previously unselected package cuda-sanitizer-12-0.
# Preparing to unpack .../44-cuda-sanitizer-12-0_12.0.90-1_amd64.deb ...
# Unpacking cuda-sanitizer-12-0 (12.0.90-1) ...
# Selecting previously unselected package cuda-command-line-tools-12-0.
# Preparing to unpack .../45-cuda-command-line-tools-12-0_12.0.0-1_amd64.deb ...
# Unpacking cuda-command-line-tools-12-0 (12.0.0-1) ...
# Selecting previously unselected package nsight-compute-2022.4.0.
# Preparing to unpack .../46-nsight-compute-2022.4.0_2022.4.0.15-1_amd64.deb ...
# Unpacking nsight-compute-2022.4.0 (2022.4.0.15-1) ...
# Selecting previously unselected package cuda-nsight-compute-12-0.
# Preparing to unpack .../47-cuda-nsight-compute-12-0_12.0.0-1_amd64.deb ...
# Unpacking cuda-nsight-compute-12-0 (12.0.0-1) ...
# Selecting previously unselected package libxcb-xinput0:amd64.
# Preparing to unpack .../48-libxcb-xinput0_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-xinput0:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package nsight-systems-2022.4.2.
# Preparing to unpack .../49-nsight-systems-2022.4.2_2022.4.2.18-1_amd64.deb ...
# Unpacking nsight-systems-2022.4.2 (2022.4.2.18-32044700v0) ...
# Selecting previously unselected package cuda-nsight-systems-12-0.
# Preparing to unpack .../50-cuda-nsight-systems-12-0_12.0.0-1_amd64.deb ...
# Unpacking cuda-nsight-systems-12-0 (12.0.0-1) ...
# Selecting previously unselected package cuda-nsight-12-0.
# Preparing to unpack .../51-cuda-nsight-12-0_12.0.78-1_amd64.deb ...
# Unpacking cuda-nsight-12-0 (12.0.78-1) ...
# Selecting previously unselected package cuda-nvml-dev-12-0.
# Preparing to unpack .../52-cuda-nvml-dev-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-nvml-dev-12-0 (12.0.76-1) ...
# Selecting previously unselected package cuda-nvvp-12-0.
# Preparing to unpack .../53-cuda-nvvp-12-0_12.0.90-1_amd64.deb ...
# Unpacking cuda-nvvp-12-0 (12.0.90-1) ...
# Selecting previously unselected package cuda-visual-tools-12-0.
# Preparing to unpack .../54-cuda-visual-tools-12-0_12.0.0-1_amd64.deb ...
# Unpacking cuda-visual-tools-12-0 (12.0.0-1) ...
# Selecting previously unselected package gds-tools-12-0.
# Preparing to unpack .../55-gds-tools-12-0_1.5.0.59-1_amd64.deb ...
# Unpacking gds-tools-12-0 (1.5.0.59-1) ...
# Selecting previously unselected package cuda-tools-12-0.
# Preparing to unpack .../56-cuda-tools-12-0_12.0.0-1_amd64.deb ...
# Unpacking cuda-tools-12-0 (12.0.0-1) ...
# Selecting previously unselected package cuda-documentation-12-0.
# Preparing to unpack .../57-cuda-documentation-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-documentation-12-0 (12.0.76-1) ...
# Selecting previously unselected package libnvvm-samples-12-0.
# Preparing to unpack .../58-libnvvm-samples-12-0_12.0.94-1_amd64.deb ...
# Unpacking libnvvm-samples-12-0 (12.0.94-1) ...
# Selecting previously unselected package cuda-toolkit-12-0.
# Preparing to unpack .../59-cuda-toolkit-12-0_12.0.0-1_amd64.deb ...
# Unpacking cuda-toolkit-12-0 (12.0.0-1) ...
# Selecting previously unselected package cuda-demo-suite-12-0.
# Preparing to unpack .../60-cuda-demo-suite-12-0_12.0.76-1_amd64.deb ...
# Unpacking cuda-demo-suite-12-0 (12.0.76-1) ...
# Selecting previously unselected package cuda-12-0.
# Preparing to unpack .../61-cuda-12-0_12.0.0-1_amd64.deb ...
# Unpacking cuda-12-0 (12.0.0-1) ...
# Selecting previously unselected package cuda.
# Preparing to unpack .../62-cuda_12.0.0-1_amd64.deb ...
# Unpacking cuda (12.0.0-1) ...
# Errors were encountered while processing:
#  /tmp/apt-dpkg-install-Edjpw3/00-cuda-toolkit-config-common_12.0.107-1_all.deb
# E: Sub-process /usr/bin/dpkg returned an error code (1)

# %% [markdown]
# 安装包

# %%
# !python3.7 -m pip uninstall pillow
# !apt-get install libjpeg-dev zlib1g-dev
# !python3.7 -m pip install pillow==4.0.0
# Out:
# WARNING: Skipping pillow as it is not installed.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2.2).
# zlib1g-dev set to manually installed.
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 21 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pillow==4.0.0
#   Using cached Pillow-4.0.0.tar.gz (11.1 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: olefile in /usr/local/lib/python3.7/dist-packages (from pillow==4.0.0) (0.46)
# Building wheels for collected packages: pillow
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for pillow (setup.py) ... error
#   ERROR: Failed building wheel for pillow
#   Running setup.py clean for pillow
# Failed to build pillow
# Installing collected packages: pillow
#   error: subprocess-exited-with-error
#
#   × Running setup.py install for pillow did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Running setup.py install for pillow ... error
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> pillow
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
# !python3.7 train.py 
!--data_dir=./img
!--val_dirs=./validation 
!--noisetype=gauss25 
!--save_model_path=./results 
!--log_name=unet_gauss25_b4e100r02 
!--increase_ratio=2
# Out:
# Traceback (most recent call last):
#   File "train.py", line 10, in <module>
#     from PIL import Image
# ModuleNotFoundError: No module named 'PIL'
# /bin/bash: --: invalid option
# Usage:	/bin/bash [GNU long option] [option] ...
# 	/bin/bash [GNU long option] [option] script-file ...
# GNU long options:
# 	--debug
# 	--debugger
# 	--dump-po-strings
# 	--dump-strings
# 	--help
# 	--init-file
# 	--login
# 	--noediting
# 	--noprofile
# 	--norc
# 	--posix
# 	--rcfile
# 	--restricted
# 	--verbose
# 	--version
# Shell options:
# 	-ilrsD or -c command or -O shopt_option		(invocation only)
# 	-abefhkmnptuvxBCHP or -o option
# /bin/bash: --: invalid option
# Usage:	/bin/bash [GNU long option] [option] ...
# 	/bin/bash [GNU long option] [option] script-file ...
# GNU long options:
# 	--debug
# 	--debugger
# 	--dump-po-strings
# 	--dump-strings
# 	--help
# 	--init-file
# 	--login
# 	--noediting
# 	--noprofile
# 	--norc
# 	--posix
# 	--rcfile
# 	--restricted
# 	--verbose
# 	--version
# Shell options:
# 	-ilrsD or -c command or -O shopt_option		(invocation only)
# 	-abefhkmnptuvxBCHP or -o option
# /bin/bash: --: invalid option
# Usage:	/bin/bash [GNU long option] [option] ...
# 	/bin/bash [GNU long option] [option] script-file ...
# GNU long options:
# 	--debug
# 	--debugger
# 	--dump-po-strings
# 	--dump-strings
# 	--help
# 	--init-file
# 	--login
# 	--noediting
# 	--noprofile
# 	--norc
# 	--posix
# 	--rcfile
# 	--restricted
# 	--verbose
# 	--version
# Shell options:
# 	-ilrsD or -c command or -O shopt_option		(invocation only)
# 	-abefhkmnptuvxBCHP or -o option
# /bin/bash: --: invalid option
# Usage:	/bin/bash [GNU long option] [option] ...
# 	/bin/bash [GNU long option] [option] script-file ...
# GNU long options:
# 	--debug
# 	--debugger
# 	--dump-po-strings
# 	--dump-strings
# 	--help
# 	--init-file
# 	--login
# 	--noediting
# 	--noprofile
# 	--norc
# 	--posix
# 	--rcfile
# 	--restricted
# 	--verbose
# 	--version
# Shell options:
# 	-ilrsD or -c command or -O shopt_option		(invocation only)
# 	-abefhkmnptuvxBCHP or -o option
# /bin/bash: --: invalid option
# Usage:	/bin/bash [GNU long option] [option] ...
# 	/bin/bash [GNU long option] [option] script-file ...
# GNU long options:
# 	--debug
# 	--debugger
# 	--dump-po-strings
# 	--dump-strings
# 	--help
# 	--init-file
# 	--login
# 	--noediting
# 	--noprofile
# 	--norc
# 	--posix
# 	--rcfile
# 	--restricted
# 	--verbose
# 	--version
# Shell options:
# 	-ilrsD or -c command or -O shopt_option		(invocation only)
# 	-abefhkmnptuvxBCHP or -o option
# /bin/bash: --: invalid option
# Usage:	/bin/bash [GNU long option] [option] ...
# 	/bin/bash [GNU long option] [option] script-file ...
# GNU long options:
# 	--debug
# 	--debugger
# 	--dump-po-strings
# 	--dump-strings
# 	--help
# 	--init-file
# 	--login
# 	--noediting
# 	--noprofile
# 	--norc
# 	--posix
# 	--rcfile
# 	--restricted
# 	--verbose
# 	--version
# Shell options:
# 	-ilrsD or -c command or -O shopt_option		(invocation only)
# 	-abefhkmnptuvxBCHP or -o option
